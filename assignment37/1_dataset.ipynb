# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread ('inputs\input_1.jpeg')
print ( img.shape )
plt.imshow (img , cmap = 'gray')
# Out:
# (600, 1200, 3)

# %%
#zero
zeros = img [ : 60 , : ]
plt.imshow (zeros , cmap = 'gray')

n = 1
for i in range (0 , zeros.shape[0] , 12) :
    for j in range (0 , zeros.shape[1] , 12) :
        zero = zeros [i : i + 12 , j : j + 12]
        adrs = f'outputs\zero\zero_{n}.jpg'
        cv2.imwrite (adrs , zero)
        n += 1

# %%
#one
ones = img [60 : 120 , : ]
plt.imshow (ones , cmap = 'gray')

n = 1
for i in range (0 , ones.shape[0] , 12) :
    for j in range (0 , ones.shape[1] , 12) :
        one = ones [i : i + 12 , j : j + 12]
        adrs = f'outputs\one\one_{n}.jpg'
        cv2.imwrite (adrs , one)
        n += 1

# %%
#two
twos = img [120 : 180 , : ]
plt.imshow (twos , cmap = 'gray')

n = 1
for i in range (0 , twos.shape[0] , 12) :
    for j in range (0 , twos.shape[1] , 12) :
        two = twos [i : i + 12 , j : j + 12]
        adrs = f'outputs\itwo\itwo_{n}.jpg'
        cv2.imwrite (adrs , two)
        n += 1

# %%
#three
threes = img [180 : 240 , : ]
plt.imshow (threes , cmap = 'gray')

n = 1
for i in range (0 , threes.shape[0] , 12) :
    for j in range (0 , threes.shape[1] , 12) :
        three = threes [i : i + 12 , j : j + 12]
        adrs = f'outputs\ithree\ithree_{n}.jpg'
        cv2.imwrite (adrs , three)
        n += 1

# %%
#four
fours = img [240 : 300 , : ]
plt.imshow (fours , cmap = 'gray')

n = 1
for i in range (0 , fours.shape[0] , 12) :
    for j in range (0 , fours.shape[1] , 12) :
        four = fours [i : i + 12 , j : j + 12]
        adrs = f'outputs\ifour\ifour_{n}.jpg'
        cv2.imwrite (adrs , four)
        n += 1

# %%
#five
fives = img [300 : 360 , : ]
plt.imshow (fives , cmap = 'gray')

n = 1
for i in range (0 , fives.shape[0] , 12) :
    for j in range (0 , fives.shape[1] , 12) :
        five = fives [i : i + 12 , j : j + 12]
        adrs = f'outputs\ifive\ifive_{n}.jpg'
        cv2.imwrite (adrs , five)
        n += 1

# %%
#six
sixs = img [360 : 420 , : ]
plt.imshow (sixs , cmap = 'gray')

n = 1
for i in range (0 , sixs.shape[0] , 12) :
    for j in range (0 , sixs.shape[1] , 12) :
        six = sixs [i : i + 12 , j : j + 12]
        adrs = f'outputs\six\six_{n}.jpg'
        cv2.imwrite (adrs , six)
        n += 1

# %%
#seven
sevens = img [420 : 480 , : ]
plt.imshow (sevens , cmap = 'gray')

n = 1
for i in range (0 , sevens.shape[0] , 12) :
    for j in range (0 , sevens.shape[1] , 12) :
        seven = sevens [i : i + 12 , j : j + 12]
        adrs = f'outputs\seven\seven_{n}.jpg'
        cv2.imwrite (adrs , seven)
        n += 1

# %%
#eight
eights = img [480 : 540 , : ]
plt.imshow (eights , cmap = 'gray')

n = 1
for i in range (0 , eights.shape[0] , 12) :
    for j in range (0 , eights.shape[1] , 12) :
        eight = eights [i : i + 12 , j : j + 12]
        adrs = f'outputs\eight\eight_{n}.jpg'
        cv2.imwrite (adrs , eight)
        n += 1

# %%
#nine
nines = img [540 : 600 , : ]
plt.imshow (nines , cmap = 'gray')

n = 1
for i in range (0 , nines.shape[0] , 12) :
    for j in range (0 , nines.shape[1] , 12) :
        nine = nines [i : i + 12 , j : j + 12]
        adrs = f'outputs\inine\inine_{n}.jpg'
        cv2.imwrite (adrs , nine)
        n += 1
