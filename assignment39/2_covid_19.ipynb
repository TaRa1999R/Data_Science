# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
data = pd.read_csv ('inputs\covid19_fullgrouped.csv')
data.head (10)
# Out:
#          Date              Country  Confirmed  Deaths  Recovered  Active  \
# 0  2020-01-22          Afghanistan          0       0          0       0
# 1  2020-01-22              Albania          0       0          0       0
# 2  2020-01-22              Algeria          0       0          0       0
# 3  2020-01-22              Andorra          0       0          0       0
# 4  2020-01-22               Angola          0       0          0       0
# 5  2020-01-22  Antigua and Barbuda          0       0          0       0
# 6  2020-01-22            Argentina          0       0          0       0
# 7  2020-01-22              Armenia          0       0          0       0
# 8  2020-01-22            Australia          0       0          0       0
# 9  2020-01-22              Austria          0       0          0       0
#
#    New cases  New deaths  New recovered             WHO Region
# 0          0           0              0  Eastern Mediterranean
# ...

# %%
data ['Date'] = pd.to_datetime (data['Date'])
data ['Month'] = data['Date'].map (lambda date : date.month)
data.head (10)
# Out:
#         Date              Country  Confirmed  Deaths  Recovered  Active  \
# 0 2020-01-22          Afghanistan          0       0          0       0
# 1 2020-01-22              Albania          0       0          0       0
# 2 2020-01-22              Algeria          0       0          0       0
# 3 2020-01-22              Andorra          0       0          0       0
# 4 2020-01-22               Angola          0       0          0       0
# 5 2020-01-22  Antigua and Barbuda          0       0          0       0
# 6 2020-01-22            Argentina          0       0          0       0
# 7 2020-01-22              Armenia          0       0          0       0
# 8 2020-01-22            Australia          0       0          0       0
# 9 2020-01-22              Austria          0       0          0       0
#
#    New cases  New deaths  New recovered             WHO Region  Month
# 0          0           0              0  Eastern Mediterranean      1
# ...

# %% [markdown]
# Fourth Month Corona Patients

# %%
fourth = data.query ('Month == 4')
month = fourth.groupby ('Country')['Active'].max().reset_index()
sorted = month.sort_values ('Active' , ascending = False).reset_index(drop = True)
sorted.head (8)
plt.table ()
# Out:
#           Country  Active
# 0              US  860358
# 1  United Kingdom  151053
# 2           Italy  108257
# 3           Spain  101617
# 4          France   98504
# 5          Russia   93806
# 6          Turkey   80808
# 7         Germany   72864

# %% [markdown]
# Death Rate In Iran

# %%
iran = data.groupby ('Countr')
